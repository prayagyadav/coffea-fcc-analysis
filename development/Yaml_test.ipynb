# %%
import json
import yaml
import os

# %%
process = {
    'collider':'FCCee',
    'campaign':'spring2021',
    'detector':'IDEA',
    'samples':['p8_ee_ZZ_ecm240','p8_ee_WW_ecm240','p8_ee_ZH_ecm240']
}
fraction = {
    'p8_ee_ZZ_ecm240':0.005,
    'p8_ee_WW_ecm240':0.5,
    'p8_ee_ZH_ecm240':0.2
}

# %%
def load_yaml_fileinfo(process):
    onlinesystem_path = '/cvmfs/fcc.cern.ch'
    localsystem_path = './../filesets'
    path = '/'.join(
        [
         'FCCDicts',
         'yaml',
         process['collider'],
         process['campaign'],
         process['detector']
        ])
    if os.path.exists(onlinesystem_path):
        print(f'Connected to {onlinesystem_path}')
        filesystem_path = onlinesystem_path
    else:
        print(onlinesystem_path+' is not available.\nTrying to find local copies of the yaml files ...')
        filesystem_path = localsystem_path
    yaml_dict = {}
    for sample in process['samples']:
        full_path = '/'.join([filesystem_path,path,sample,'merge.yaml'])
        try :
            with open(full_path) as f:
                dict = yaml.safe_load(f)
            print('Loaded : '+full_path)
            # print(dict)
        except:
            raise f'Could not find yaml files at {filesystem_path} .'
        yaml_dict[sample] = dict
    return yaml_dict

# %%
def get_fileset(yaml_dict, fraction, skipbadfiles=True):
    output_fileset_dictionary = {}
    print('_________Loading fileset__________')
    for key in yaml_dict.keys():
        output_fileset_dictionary[key] = {}
        # nbad = yaml_dict[key]['merge']['nbad']
        # ndone = yaml_dict[key]['merge']['ndone']
        nevents = yaml_dict[key]['merge']['nevents']
        outdir = yaml_dict[key]['merge']['outdir']
        outfiles = yaml_dict[key]['merge']['outfiles']
        outfilesbad = yaml_dict[key]['merge']['outfilesbad']
        proc = yaml_dict[key]['merge']['process']
        # size = yaml_dict[key]['merge']['size']
        # sumofweights = yaml_dict[key]['merge']['sumofweights']
        out = np.array(outfiles)
        bad = np.array(outfilesbad)
        
        # Remove bad files
        if (bad.size != 0) & skipbadfiles :
            filenames_bad = bad[:,0]
            y = out
            for row in range(out.shape[0]) :
                file = out[row,0]
                if file in filenames_bad:
                    y = np.delete(y , (row), axis=0)
            out = y

        filenames = out[:,0]
        file_events = out[:,1].astype('int32')
        cumulative_events = np.cumsum(file_events)
    
        frac = fraction[proc]
        needed_events = frac*nevents

        #get closest value and index to the needed events
        index = np.abs(cumulative_events - needed_events).argmin() 
        assigned_events = cumulative_events[index]
        assigned_files = filenames[:index+1]

        # Summary
        print('----------------------------------')
        print(f'----------{key}---------')
        print('----------------------------------')
        print(f'Total available events = {nevents}')
        print(f'Fraction needed = {frac}')
        print(f'Needed events = {needed_events}')
        print(f'Assigned events = {assigned_events}')
        print(f'Number of files = {len(assigned_files)}')
        print('Files:')

        # At the same time get the dictionary
        fileset_by_key = {}
        for file in assigned_files:
            print(f'\t {outdir+file}')
            fileset_by_key[outdir+file] = 'events'
        output_fileset_dictionary[key]['files'] = fileset_by_key
    return output_fileset_dictionary

# %%
yaml_dict = load_yaml_fileinfo(process)
# Out:
# /cvmfs/fcc.cern.ch is not available.
# Trying to find local copies of the yaml files ...
# Loaded : ./../filesets/FCCDicts/yaml/FCCee/spring2021/IDEA/p8_ee_ZZ_ecm240/merge.yaml
# Loaded : ./../filesets/FCCDicts/yaml/FCCee/spring2021/IDEA/p8_ee_WW_ecm240/merge.yaml
# Loaded : ./../filesets/FCCDicts/yaml/FCCee/spring2021/IDEA/p8_ee_ZH_ecm240/merge.yaml

# %%
get_fileset(yaml_dict,fraction)
# Out:
# _________Loading fileset__________
# ----------------------------------
# ----------p8_ee_ZZ_ecm240---------
# ----------------------------------
# Total available events = 59800000
# Fraction needed = 0.005
# Needed events = 299000.0
# Assigned events = 300000
# Number of files = 3
# Files:
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZZ_ecm240/events_000203378.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZZ_ecm240/events_001062578.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZZ_ecm240/events_001109319.root
# ----------------------------------
# ----------p8_ee_WW_ecm240---------
# ----------------------------------
# Total available events = 10000000
# Fraction needed = 0.5
# Needed events = 5000000.0
# Assigned events = 5000000
# Number of files = 50
# Files:
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_002446962.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_003660780.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_003871346.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_006111023.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_006917088.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_007700274.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_009698995.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_014553223.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_015203393.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_016976279.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_018665926.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_018713241.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_019837840.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_023471508.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_026468529.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_027476245.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_028807086.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_028914696.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_030994453.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_031800883.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_032306830.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_036566822.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_039767239.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_040168535.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_041868503.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_042960849.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_045685798.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_046174706.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_046854584.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_049408485.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_050421846.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_051087029.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_051591218.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_057156831.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_057603313.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_057691795.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_059017045.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_063234923.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_065752700.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_070028470.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_070650542.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_072894802.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_073177487.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_073916792.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_074962718.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_076184375.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_078174375.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_081552316.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_087150860.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_087671235.root
# ----------------------------------
# ----------p8_ee_ZH_ecm240---------
# ----------------------------------
# Total available events = 10000000
# Fraction needed = 0.2
# Needed events = 2000000.0
# Assigned events = 2000000
# Number of files = 20
# Files:
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_002125352.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_004864728.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_008903100.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_014692952.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_018575502.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_022606167.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_023301643.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_025023196.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_029706955.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_031985013.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_032939801.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_034891952.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_034912729.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_037707607.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_038855885.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_041407970.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_043299326.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_045124915.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_046318292.root
# 	 /eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_048296984.root
# {'p8_ee_ZZ_ecm240': {'files': {'/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZZ_ecm240/events_000203378.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZZ_ecm240/events_001062578.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZZ_ecm240/events_001109319.root': 'events'}},
#  'p8_ee_WW_ecm240': {'files': {'/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_002446962.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_003660780.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_003871346.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_006111023.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_006917088.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_007700274.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_009698995.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_014553223.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_015203393.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_016976279.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_018665926.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_018713241.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_019837840.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_023471508.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_026468529.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_027476245.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_028807086.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_028914696.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_030994453.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_031800883.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_032306830.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_036566822.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_039767239.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_040168535.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_041868503.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_042960849.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_045685798.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_046174706.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_046854584.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_049408485.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_050421846.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_051087029.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_051591218.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_057156831.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_057603313.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_057691795.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_059017045.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_063234923.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_065752700.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_070028470.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_070650542.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_072894802.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_073177487.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_073916792.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_074962718.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_076184375.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_078174375.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_081552316.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_087150860.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_WW_ecm240/events_087671235.root': 'events'}},
#  'p8_ee_ZH_ecm240': {'files': {'/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_002125352.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_004864728.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_008903100.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_014692952.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_018575502.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_022606167.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_023301643.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_025023196.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_029706955.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_031985013.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_032939801.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_034891952.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_034912729.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_037707607.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_038855885.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_041407970.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_043299326.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_045124915.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_046318292.root': 'events',
#    '/eos/experiment/fcc/ee/generation/DelphesEvents/spring2021/IDEA/p8_ee_ZH_ecm240/events_048296984.root': 'events'}}}

# %%
process = 'p8_ee_ZZ_ecm240'
nbad = yaml_dict[process]['merge']['nbad']
ndone = yaml_dict[process]['merge']['ndone']
nevents = yaml_dict[process]['merge']['nevents']
outdir = yaml_dict[process]['merge']['outdir']
outfiles = yaml_dict[process]['merge']['outfiles']
outfilesbad = yaml_dict[process]['merge']['outfilesbad']
process = yaml_dict[process]['merge']['process']
size = yaml_dict[process]['merge']['size']
sumofweights = yaml_dict[process]['merge']['sumofweights']

# %%
import numpy as np

# %%
out = np.array(outfiles)

# %%
out[:,1].astype('int32')
# Out:
# array([100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000,
#        100000, 100000, 100000, 100000, 100000, 100000], dtype=int32)

# %%
c = np.cumsum(out[:,1].astype('int32'))
c
# Out:
# array([  100000,   200000,   300000,   400000,   500000,   600000,
#          700000,   800000,   900000,  1000000,  1100000,  1200000,
#         1300000,  1400000,  1500000,  1600000,  1700000,  1800000,
#         1900000,  2000000,  2100000,  2200000,  2300000,  2400000,
#         2500000,  2600000,  2700000,  2800000,  2900000,  3000000,
#         3100000,  3200000,  3300000,  3400000,  3500000,  3600000,
#         3700000,  3800000,  3900000,  4000000,  4100000,  4200000,
#         4300000,  4400000,  4500000,  4600000,  4700000,  4800000,
#         4900000,  5000000,  5100000,  5200000,  5300000,  5400000,
#         5500000,  5600000,  5700000,  5800000,  5900000,  6000000,
#         6100000,  6200000,  6300000,  6400000,  6500000,  6600000,
#         6700000,  6800000,  6900000,  7000000,  7100000,  7200000,
#         7300000,  7400000,  7500000,  7600000,  7700000,  7800000,
#         7900000,  8000000,  8100000,  8200000,  8300000,  8400000,
#         8500000,  8600000,  8700000,  8800000,  8900000,  9000000,
#         9100000,  9200000,  9300000,  9400000,  9500000,  9600000,
#         9700000,  9800000,  9900000, 10000000, 10100000, 10200000,
#        10300000, 10400000, 10500000, 10600000, 10700000, 10800000,
#        10900000, 11000000, 11100000, 11200000, 11300000, 11400000,
#        11500000, 11600000, 11700000, 11800000, 11900000, 12000000,
#        12100000, 12200000, 12300000, 12400000, 12500000, 12600000,
#        12700000, 12800000, 12900000, 13000000, 13100000, 13200000,
#        13300000, 13400000, 13500000, 13600000, 13700000, 13800000,
#        13900000, 14000000, 14100000, 14200000, 14300000, 14400000,
#        14500000, 14600000, 14700000, 14800000, 14900000, 15000000,
#        15100000, 15200000, 15300000, 15400000, 15500000, 15600000,
#        15700000, 15800000, 15900000, 16000000, 16100000, 16200000,
#        16300000, 16400000, 16500000, 16600000, 16700000, 16800000,
#        16900000, 17000000, 17100000, 17200000, 17300000, 17400000,
#        17500000, 17600000, 17700000, 17800000, 17900000, 18000000,
#        18100000, 18200000, 18300000, 18400000, 18500000, 18600000,
#        18700000, 18800000, 18900000, 19000000, 19100000, 19200000,
#        19300000, 19400000, 19500000, 19600000, 19700000, 19800000,
#        19900000, 20000000, 20100000, 20200000, 20300000, 20400000,
#        20500000, 20600000, 20700000, 20800000, 20900000, 21000000,
#        21100000, 21200000, 21300000, 21400000, 21500000, 21600000,
#        21700000, 21800000, 21900000, 22000000, 22100000, 22200000,
#        22300000, 22400000, 22500000, 22600000, 22700000, 22800000,
#        22900000, 23000000, 23100000, 23200000, 23300000, 23400000,
#        23500000, 23600000, 23700000, 23800000, 23900000, 24000000,
#        24100000, 24200000, 24300000, 24400000, 24500000, 24600000,
#        24700000, 24800000, 24900000, 25000000, 25100000, 25200000,
#        25300000, 25400000, 25500000, 25600000, 25700000, 25800000,
#        25900000, 26000000, 26100000, 26200000, 26300000, 26400000,
#        26500000, 26600000, 26700000, 26800000, 26900000, 27000000,
#        27100000, 27200000, 27300000, 27400000, 27500000, 27600000,
#        27700000, 27800000, 27900000, 28000000, 28100000, 28200000,
#        28300000, 28400000, 28500000, 28600000, 28700000, 28800000,
